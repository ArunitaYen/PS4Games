# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import seaborn as sns

# %%
os.chdir("C:\\Users\Sweta\OneDrive\Desktop\DELHI")

# %%
df=pd.read_csv("6-PS4_GamesSales.csv")

# %%
df.info
# Out:
# <bound method DataFrame.info of                                     Game    Year             Genre  \
# 0                     Grand Theft Auto V  2014.0            Action
# 1              Call of Duty: Black Ops 3  2015.0           Shooter
# 2                  Red Dead Redemption 2  2018.0  Action-Adventure
# 3                     Call of Duty: WWII  2017.0           Shooter
# 4                                FIFA 18  2017.0            Sports
# ...                                  ...     ...               ...
# 1029  Fallen Legion: Flames of Rebellion     NaN      Role-Playing
# 1030            Radial G Racing Revolved  2017.0            Racing
# 1031                The Mummy Demastered     NaN            Action
# 1032          Project Nimbus: Code Mirai     NaN            Action
# 1033                 Battle Chef Brigade     NaN            Action
#
#            Publisher  North America  Europe  Japan  Rest of World  Global
# ...

# %%
df.head()
# Out:
#                         Game    Year             Genre       Publisher  \
# 0         Grand Theft Auto V  2014.0            Action  Rockstar Games
# 1  Call of Duty: Black Ops 3  2015.0           Shooter      Activision
# 2      Red Dead Redemption 2  2018.0  Action-Adventure  Rockstar Games
# 3         Call of Duty: WWII  2017.0           Shooter      Activision
# 4                    FIFA 18  2017.0            Sports       EA Sports
#
#    North America  Europe  Japan  Rest of World  Global
# 0           6.06    9.71   0.60           3.02   19.39
# 1           6.18    6.05   0.41           2.44   15.09
# 2           5.26    6.21   0.21           2.26   13.94
# 3           4.67    6.21   0.40           2.12   13.40
# 4           1.27    8.64   0.15           1.73   11.80

# %%
#to check number of Publisher
df.Publisher.unique()
# Out:
# array(['Rockstar Games', 'Activision', 'EA Sports', 'Electronic Arts',
#        'Sony Interactive Entertainment', 'Bethesda Softworks',
#        'Sony Computer Entertainment', 'Namco Bandai Games', 'Square Enix',
#        'Capcom', 'Blizzard Entertainment', 'Ubisoft',
#        'Warner Bros. Interactive', '2K Sports',
#        'Warner Bros. Interactive Entertainment',
#        'Konami Digital Entertainment', '2K Games', 'Hello Games',
#        '505 Games', 'Deep Silver', 'Take-Two Interactive',
#        'Bandai Namco Games', 'Sega', 'Tecmo Koei', 'Gearbox Software',
#        'Mojang', 'Disney Interactive Studios', 'Focus Home Interactive',
#        'Studio Wildcard', 'Codemasters', 'Koch Media',
#        'Harmonix Music Systems', 'Rebellion Developments', 'Gun Media',
#        'Telltale Games', 'Kalypso Media', 'City Interactive',
#        'NIS America', 'Sold Out', 'Tripwire Interactive', 'PQube',
#        'THQ Nordic', 'Milestone S.r.l.', 'Nordic Games', 'Astragon',
# ...

# %%
#to check all different types of Genre 
df.Genre.unique()
# Out:
# array(['Action', 'Shooter', 'Action-Adventure', 'Sports', 'Role-Playing',
#        'Misc', 'Platform', 'Racing', 'Fighting', 'Adventure', 'MMO',
#        'Simulation', 'Music', 'Party', 'Strategy', 'Puzzle',
#        'Visual Novel'], dtype=object)

# %%
plt.subplots(figsize = (8,4))
plt.hist(df.Year,bins=20)
plt.show()

# %%
rockstar = df[df.Publisher == 'Rockstar Games']
activision = df[df.Publisher == 'Activision']
sony = df[df.Publisher == 'Sony Interactive Entertainment']
eas = df[df.Publisher == 'EA Sports']

# %%
plt.subplots(figsize = (8,4))
plt.hist(rockstar.Game)
plt.show()

# %%
plt.subplots(figsize = (8,4))
plt.scatter(rockstar.Year,rockstar['North America'],color = 'red')
plt.xlabel('Year')
plt.ylabel('North America Sale')
plt.show()

# %%
plt.subplots(figsize = (8,4))
plt.scatter(rockstar.Year,rockstar['Europe'],color = 'red')
plt.xlabel('Year')
plt.ylabel('Europe Sale')
plt.show()

# %%
plt.subplots(figsize = (8,4))
plt.scatter(rockstar.Year,rockstar['Europe'],color = 'red')
plt.xlabel('Year')
plt.ylabel('Europe Sale')

# %%
plt.subplots(figsize = (8,4))
plt.scatter(rockstar.Year,rockstar['Japan'],color = 'red')
plt.xlabel('Year')
plt.ylabel('Japan Sale')
# Out:
# Text(0, 0.5, 'Japan Sale')

# %%
plt.subplots(figsize = (8,4))
plt.scatter(rockstar.Year,rockstar['Global'],color = 'red')
plt.xlabel('Year')
plt.ylabel('Global Sale')
# Out:
# Text(0, 0.5, 'Global Sale')

# %%
activision.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 1 to 918
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Game           30 non-null     object
#  1   Year           30 non-null     float64
#  2   Genre          30 non-null     object
#  3   Publisher      30 non-null     object
#  4   North America  30 non-null     float64
#  5   Europe         30 non-null     float64
#  6   Japan          30 non-null     float64
#  7   Rest of World  30 non-null     float64
#  8   Global         30 non-null     float64
# dtypes: float64(6), object(3)
# memory usage: 2.3+ KB

# %%
plt.subplots(figsize = (8,4))
plt.hist(activision.Game,bins = 100)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.subplots(figsize = (8,4))
plt.scatter(activision.Year,activision['North America'],color = 'red')
plt.xlabel('Year')
plt.ylabel('North America Sale')
plt.show()

# %%
plt.subplots(figsize = (8,4))
plt.scatter(activision.Year,activision['Europe'],color = 'red')
plt.xlabel('Year')
plt.ylabel('Europe Sale')
plt.show()

# %%
plt.subplots(figsize = (8,4))
plt.scatter(activision.Year,activision.Japan,color = 'red')
plt.xlabel('Year')
plt.ylabel('Japan Sale')
plt.show()

# %%
plt.subplots(figsize = (8,4))
plt.scatter(activision.Year,activision.Global,color = 'red',alpha = 0.5)
plt.xlabel('Year')
plt.ylabel('Global Sale')
plt.show()

# %%
plt.subplots(figsize = (10,5))
plt.hist(sony.Game,bins = 200)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.subplots(figsize = (8,4))
plt.scatter(sony.Year,sony['North America'],color = 'red')
plt.xlabel('Year')
plt.ylabel('North America Sale')
plt.show()

# %%
plt.subplots(figsize = (8,4))
plt.scatter(sony.Year,sony['Europe'],color = 'red')
plt.xlabel('Year')
plt.ylabel('Europe Sale')
plt.show()

# %%
plt.subplots(figsize = (8,4))
plt.scatter(sony.Year,sony['Japan'],color = 'red')
plt.xlabel('Year')
plt.ylabel('Japan Sale')
plt.show()

# %%
plt.subplots(figsize = (8,4))
plt.scatter(sony.Year,sony['Global'],color = 'red')
plt.xlabel('Year')
plt.ylabel('Global Sale')
plt.show()

# %%
plt.subplots(figsize = (8,4))
plt.hist(eas.Game,bins = 100)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.subplots(figsize = (8,4))
plt.scatter(eas.Year,eas['North America'],color = 'red')
plt.xlabel('Year')
plt.ylabel('North America Sale')
plt.show()

# %%
plt.subplots(figsize = (8,4))
plt.scatter(eas.Year,eas['Europe'],color = 'red')
plt.xlabel('Year')
plt.ylabel('Europe Sale')
plt.show()

# %%
plt.subplots(figsize = (8,4))
plt.scatter(eas.Year,eas['Japan'],color = 'red')
plt.xlabel('Year')
plt.ylabel('Japan Sale')
plt.show()

# %%
plt.subplots(figsize = (8,4))
plt.scatter(eas.Year,eas['Global'],color = 'red')
plt.xlabel('Year')
plt.ylabel('Global Sale')
plt.show()

# %%
plt.subplots(figsize = (8,4))
plt.plot(rockstar.Global,rockstar['North America'],color = 'red',label = 'North America')
plt.plot(rockstar.Global,rockstar['Europe'],color = 'green',label = 'Europe')
plt.plot(rockstar.Global,rockstar['Japan'],color = 'blue',label = 'Japan')
plt.plot(rockstar.Global,rockstar['Rest of World'],color = 'orange',label = 'Rest of World')
plt.legend()
plt.xlabel('Global Sale')
plt.show()

# %%
plt.subplots(figsize = (8,4))
plt.plot(activision.Global,activision['North America'],color = 'red',label = 'North America')
plt.plot(activision.Global,activision['Europe'],color = 'green',label = 'Europe')
plt.plot(activision.Global,activision['Japan'],color = 'blue',label = 'Japan')
plt.plot(activision.Global,activision['Rest of World'],color = 'orange',label = 'Rest of World')
plt.legend()
plt.xlabel('Global Sale')
plt.show()

# %%
plt.subplots(figsize = (8,4))
plt.plot(sony.Global,sony['North America'],color = 'red',label = 'North America')
plt.plot(sony.Global,sony['Europe'],color = 'green',label = 'Europe')
plt.plot(sony.Global,sony['Japan'],color = 'blue',label = 'Japan')
plt.plot(sony.Global,sony['Rest of World'],color = 'orange',label = 'Rest of World')
plt.legend()
plt.xlabel('Global Sale')
plt.show()

# %%
plt.subplots(figsize = (8,4))
plt.plot(eas.Global,eas['North America'],color = 'red',label = 'North America')
plt.plot(eas.Global,eas['Europe'],color = 'green',label = 'Europe')
plt.plot(eas.Global,eas['Japan'],color = 'blue',label = 'Japan')
plt.plot(eas.Global,eas['Rest of World'],color = 'orange',label = 'Rest of World')
plt.legend()
plt.xlabel('Global Sale')
plt.show()

# %%
eas.head()
# Out:
#               Game    Year   Genre  Publisher  North America  Europe  Japan  \
# 4          FIFA 18  2017.0  Sports  EA Sports           1.27    8.64   0.15
# 10         FIFA 16  2015.0  Sports  EA Sports           1.15    5.77   0.07
# 16         FIFA 15  2014.0  Sports  EA Sports           0.83    4.49   0.05
# 43  FIFA Soccer 14  2013.0  Sports  EA Sports           0.62    2.18   0.12
# 48   Madden NFL 16  2015.0  Sports  EA Sports           2.39    0.31   0.00
#
#     Rest of World  Global
# 4            1.73   11.80
# 10           1.23    8.22
# 16           0.94    6.32
# 43           0.51    3.43
# 48           0.61    3.30
